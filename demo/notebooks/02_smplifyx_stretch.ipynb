# %% [markdown]
# # 02 — STRETCH GOAL: SMPLify-X optimization path
#
# **Hard cutoff**: 5/5 EOD. Skip if the main pipeline notebook (`01`) is not green by then.
#
# This notebook converts the same HRNet 2D keypoints used in `01` into BODY_25
# OpenPose format, runs the SMPLify-X CLI fitter, and reports the per-image
# **joint agreement** (mm) between the optimization output and HMR 2.0's regression
# output (loaded from `01`'s saved npz).
#
# Per codex round-1 review: this is *agreement*, not *accuracy*.  True
# PA-MPJPE accuracy comes from the original papers' Human3.6M / 3DPW numbers,
# which we cite in the report §4.

# %%
# Pre-conditions:
#   - env_smplifyx conda env activated (separate from main pipeline env)
#   - SMPLify-X cloned: git clone https://github.com/vchoutas/smplify-x.git
#   - hrnet_kpts.npz produced by Notebook 01

import sys; sys.path.insert(0, '..')
from demo.src.smplifyx_cli import write_smplifyx_input, run_smplifyx_cli
from pathlib import Path

# Load HRNet 2D keypoints saved by Notebook 01
import numpy as np
data = np.load('../results/hrnet_kpts.npz')

# TODO: implement when stretch is green; see demo/src/smplifyx_cli.py docstring

# %% [markdown]
# If stretch fails: skip this notebook, report only HRNet+HMR2 in `01`.
